# %% [markdown]
# <a href="https://colab.research.google.com/github/Xushnudbek76/computer-vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

downloader.download("kebab shashlik grilled meat food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik grilled meat food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://dirtydishesmessykisses.com/wp-content/uploads/2024/11/authentic-turkish-doner-kebab-recipe-1732017060.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://www.jocooks.com/wp-content/uploads/2023/04/chicken-doner-kebab-1.jpg
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf /content/drive/
# Out:
# rm: cannot remove '/content/drive/MyDrive': Operation canceled
# rm: cannot remove '/content/drive/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove '/content/drive/.Trash-0': Directory not empty
# rm: cannot remove '/content/drive/.Encrypted/MyDrive': Operation canceled
# rm: cannot remove '/content/drive/.Encrypted/.shortcut-targets-by-id': Operation canceled

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shashlik grilled meat food'
target_dir = '/content/drive/MyDrive/food-dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

print("Done! All images moved to:", target_dir)
# Out:
# Done! All images moved to: /content/drive/MyDrive/food-dataset/kebab
